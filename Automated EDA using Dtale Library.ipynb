# %%
pip install dtale
# Out:
# ...
#                                               0.0/14.2 MB ? eta -:--:--
#                                               0.0/14.2 MB 1.4 MB/s eta 0:00:11
#                                              0.0/14.2 MB 495.5 kB/s eta 0:00:29
#                                              0.1/14.2 MB 544.7 kB/s eta 0:00:27
#                                              0.1/14.2 MB 656.4 kB/s eta 0:00:22
#                                              0.2/14.2 MB 706.2 kB/s eta 0:00:20
#                                              0.2/14.2 MB 778.2 kB/s eta 0:00:19
#                                              0.3/14.2 MB 827.5 kB/s eta 0:00:17
#                                              0.3/14.2 MB 863.3 kB/s eta 0:00:17
#                                              0.4/14.2 MB 857.5 kB/s eta 0:00:17
#      -                                       0.4/14.2 MB 881.6 kB/s eta 0:00:16
#      -                                       0.5/14.2 MB 901.1 kB/s eta 0:00:16
# ...

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
dataframe = sns.load_dataset("titanic")

# %%
dataframe
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import dtale as dt

# %%
dt.show(dataframe)
# Out:
# c:\program files\python38\lib\site-packages\dtale\views.py:785: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Shabab:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# c:\program files\python38\lib\site-packages\dtale\charts\utils.py:899: FutureWarning:
#
# In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#
# c:\program files\python38\lib\site-packages\dtale\charts\utils.py:899: FutureWarning:
#
# ...

# %%
dt.show(dataframe).kill()
# Out:
# c:\program files\python38\lib\site-packages\dtale\views.py:785: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#
# 2023-10-09 23:36:02,974 - INFO     - Executing shutdown...
# 2023-10-09 23:36:02,974 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
